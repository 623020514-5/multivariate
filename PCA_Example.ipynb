# %% [markdown]
# <a href="https://colab.research.google.com/github/623020514-5/multivariate/blob/main/PCA_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('nndb_flat.csv')
data.head(10)
# Out:
#      ID               FoodGroup  ... Selenium_USRDA Zinc_USRDA
# 0  1001  Dairy and Egg Products  ...       0.018182   0.008182
# 1  1002  Dairy and Egg Products  ...       0.018182   0.004545
# 2  1003  Dairy and Egg Products  ...       0.000000   0.000909
# 3  1004  Dairy and Egg Products  ...       0.263636   0.241818
# 4  1005  Dairy and Egg Products  ...       0.263636   0.236364
# 5  1006  Dairy and Egg Products  ...       0.263636   0.216364
# 6  1007  Dairy and Egg Products  ...       0.263636   0.216364
# 7  1008  Dairy and Egg Products  ...       0.263636   0.267273
# 8  1009  Dairy and Egg Products  ...       0.514545   0.311818
# 9  1010  Dairy and Egg Products  ...       0.263636   0.253636
#
# [10 rows x 45 columns]

# %% [markdown]
# ตรวจสอบข้อมูลว่ามี data กี่ตัว dimention
#
# 1.   List item
# 2.   List item

# %%
data.shape
# Out:
# (8618, 45)

# %% [markdown]
# ลอง plot scatter

# %%
pd.plotting.scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b98a81450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b9a0f4650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b98a9cf50>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b98504990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b9853af10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b984fa4d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b984aea50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b9845ab10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b98427590>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b97c5e390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b97c13910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b97bc6e90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b97b8a450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b97b3e9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b97b76f50>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b973a6d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b9736a310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b9731e890>],
#        ...,
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc727f2d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc744b850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc74a0dd0>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bcda67bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bcdb13190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bcdd26710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bcdd09c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bce43e250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bce41e7d0>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bb70275d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bb7111b50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bb721a110>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bb7664690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bb7868090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bb7b30c10>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bba9f4050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bbaa1b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bbaa72ad0>]],
#       dtype=object)

# %% [markdown]
# เนื่องจาก Data มี dimention มากเกินไป เราจะทดสอบดูว่า column ใด ให้ข้อมูลซ้ำกับ column อื่น แล้วลบมันออก

# %%
newdata = data.iloc[:,7:]
newdata.head()
# Out:
#    Energy_kcal  Protein_g  Fat_g  ...  Phosphorus_USRDA  Selenium_USRDA  Zinc_USRDA
# 0        717.0       0.85  81.11  ...          0.034286        0.018182    0.008182
# 1        717.0       0.85  81.11  ...          0.032857        0.018182    0.004545
# 2        876.0       0.28  99.48  ...          0.004286        0.000000    0.000909
# 3        353.0      21.40  28.74  ...          0.552857        0.263636    0.241818
# 4        371.0      23.24  29.68  ...          0.644286        0.263636    0.236364
#
# [5 rows x 38 columns]

# %% [markdown]
# ตรวจสอบว่า ระหว่าง columns มี correlation กันมากน้อยแค่ไหน ด้วย numpy

# %%
import numpy as np

# %%
corr = np.corrcoef(newdata.to_numpy().T)

# %%
corr
# Out:
# array([[1.        , 0.11030203, 0.80679472, ..., 0.19518065, 0.05667274,
#         0.11276635],
#        [0.11030203, 1.        , 0.05471538, ..., 0.44460761, 0.37836917,
#         0.41631538],
#        [0.80679472, 0.05471538, 1.        , ..., 0.06608644, 0.03755914,
#         0.02826352],
#        ...,
#        [0.19518065, 0.44460761, 0.06608644, ..., 1.        , 0.22368557,
#         0.26657694],
#        [0.05667274, 0.37836917, 0.03755914, ..., 0.22368557, 1.        ,
#         0.20529859],
#        [0.11276635, 0.41631538, 0.02826352, ..., 0.26657694, 0.20529859,
#         1.        ]])

# %%
for i in range(corr.shape[0]): 
   for j in range(corr.shape[1]):
      if (i !=j) and (corr[i,j] == 1.):
        print(f'row = {i} column = {j} corrcoef = {corr[i,j]}')
# Out:
# row = 10 column = 27 corrcoef = 1.0
# row = 12 column = 29 corrcoef = 1.0
# row = 13 column = 30 corrcoef = 1.0
# row = 14 column = 31 corrcoef = 1.0
# row = 18 column = 34 corrcoef = 1.0
# row = 20 column = 35 corrcoef = 1.0
# row = 22 column = 37 corrcoef = 1.0
# row = 27 column = 10 corrcoef = 1.0
# row = 29 column = 12 corrcoef = 1.0
# row = 30 column = 13 corrcoef = 1.0
# row = 31 column = 14 corrcoef = 1.0
# row = 34 column = 18 corrcoef = 1.0
# row = 35 column = 20 corrcoef = 1.0
# row = 37 column = 22 corrcoef = 1.0

# %%
newdata.iloc[:5,11:29]
# Out:
#    Folate_mcg  Niacin_mg  Riboflavin_mg  ...  VitC_USRDA  VitE_USRDA  Folate_USRDA
# 0         3.0      0.042          0.034  ...         0.0    0.154667        0.0075
# 1         3.0      0.042          0.034  ...         0.0    0.154667        0.0075
# 2         0.0      0.003          0.005  ...         0.0    0.186667        0.0000
# 3        36.0      1.016          0.382  ...         0.0    0.016667        0.0900
# 4        20.0      0.118          0.351  ...         0.0    0.017333        0.0500
#
# [5 rows x 18 columns]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(newdata.iloc[:,11],newdata.iloc[:,28])

# %%
plt.plot(newdata.iloc[:,11],newdata.iloc[:,28],'r.')

# %% [markdown]
# ตรวจสอบขนาดของข้อมูลว่ามี data กี่ตัว และมีกี่ dimensions

# %%
data.shape
# Out:
# (8618, 45)

# %% [markdown]
# ลอง plot scatter matrix เพื่อดูการกระจายของ data ในมุมมองต่างๆ

# %%
pd.plotting.scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bbe4ed510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc023e810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc0230350>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc1646e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc1697410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc16b2990>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc16c6f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc173b4d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc173abd0>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc1e29850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc1e7add0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc1eb8390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc1ee3910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc1f41e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc1fbcad0>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc2918250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc295f7d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7bc29f5d50>],
#        ...,
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b849e5810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b8499bd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b8495c350>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b84196150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b8414d6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b84103c50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b840c5210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b840fb790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b840b2d10>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b838edb10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b838af0d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b83865650>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7b8381abd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b837dd190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b83792710>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b82fcd510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b82f85a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7b82fbafd0>]],
#       dtype=object)

# %% [markdown]
# เนื่องจาก Data มี dimension มากเกินไป เราจะทดสอบดูว่า column ใด ให้ข้อมูลซ้ำกับ column อื่น แล้วลบมันออก
# เลือกมาทำต่อเฉพาะข้อมูลที่เป็นตัวเลข

# %%
newdata = data.iloc[:,7:]
newdata.head()
# Out:
#    Energy_kcal  Protein_g  Fat_g  ...  Phosphorus_USRDA  Selenium_USRDA  Zinc_USRDA
# 0        717.0       0.85  81.11  ...          0.034286        0.018182    0.008182
# 1        717.0       0.85  81.11  ...          0.032857        0.018182    0.004545
# 2        876.0       0.28  99.48  ...          0.004286        0.000000    0.000909
# 3        353.0      21.40  28.74  ...          0.552857        0.263636    0.241818
# 4        371.0      23.24  29.68  ...          0.644286        0.263636    0.236364
#
# [5 rows x 38 columns]

# %% [markdown]
# ตรวจสอบว่า ระหว่าง columns มี correlation กันมากน้อยแค่ไหน ด้วย numpy

# %%
import numpy as np

# %%
corr = np.corrcoef(newdata.to_numpy().T)

# %%
corr.shape
# Out:
# (38, 38)

# %%
corr
# Out:
# array([[1.        , 0.11030203, 0.80679472, ..., 0.19518065, 0.05667274,
#         0.11276635],
#        [0.11030203, 1.        , 0.05471538, ..., 0.44460761, 0.37836917,
#         0.41631538],
#        [0.80679472, 0.05471538, 1.        , ..., 0.06608644, 0.03755914,
#         0.02826352],
#        ...,
#        [0.19518065, 0.44460761, 0.06608644, ..., 1.        , 0.22368557,
#         0.26657694],
#        [0.05667274, 0.37836917, 0.03755914, ..., 0.22368557, 1.        ,
#         0.20529859],
#        [0.11276635, 0.41631538, 0.02826352, ..., 0.26657694, 0.20529859,
#         1.        ]])

# %%
for i in range(corr.shape[0]):
    for j in range(corr.shape[1]):
        if (i !=j) and (corr[i,j] == 1.):
            print(f'row = {i} column = {j} corrcoef = {corr[i,j]}')
# Out:
# row = 10 column = 27 corrcoef = 1.0
# row = 12 column = 29 corrcoef = 1.0
# row = 13 column = 30 corrcoef = 1.0
# row = 14 column = 31 corrcoef = 1.0
# row = 18 column = 34 corrcoef = 1.0
# row = 20 column = 35 corrcoef = 1.0
# row = 22 column = 37 corrcoef = 1.0
# row = 27 column = 10 corrcoef = 1.0
# row = 29 column = 12 corrcoef = 1.0
# row = 30 column = 13 corrcoef = 1.0
# row = 31 column = 14 corrcoef = 1.0
# row = 34 column = 18 corrcoef = 1.0
# row = 35 column = 20 corrcoef = 1.0
# row = 37 column = 22 corrcoef = 1.0

# %%
newdata.iloc[:5,10:30]
# Out:
#    VitE_mg  Folate_mcg  Niacin_mg  ...  VitE_USRDA  Folate_USRDA  Niacin_USRDA
# 0     2.32         3.0      0.042  ...    0.154667        0.0075      0.002625
# 1     2.32         3.0      0.042  ...    0.154667        0.0075      0.002625
# 2     2.80         0.0      0.003  ...    0.186667        0.0000      0.000188
# 3     0.25        36.0      1.016  ...    0.016667        0.0900      0.063500
# 4     0.26        20.0      0.118  ...    0.017333        0.0500      0.007375
#
# [5 rows x 20 columns]

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# data ที่มี correlation เป็น 1

# %%
plt.plot(newdata.iloc[:,10],newdata.iloc[:,27],'r.')

# %% [markdown]
# data ที่มี correlation เป็นค่าอื่นๆ

# %%
plt.plot(newdata.iloc[:,11],newdata.iloc[:,29],'r.'
# Out:
#   File "<ipython-input-73-c68dfc92748f>", line 1
#     plt.plot(newdata.iloc[:,11],newdata.iloc[:,29],'r.'
#                                                        ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ลบ column ซ้ำ

# %%
newdata.columns.str.contains('_USRDA')

# %%
newdata.columns[newdata.columns.str.contains('_USRDA')].values

# %%
newdata.drop(newdata.columns[newdata.columns.str.contains('_USRDA')].values,axis=1)

# %% [markdown]
# # Quiz1 ลบ columns ที่มีค่า correlation เป็น 1 เมื่อเทียบกับ column อื่น

# %%
newdata.columns.str.contains('_mg')

# %%
newdata.columns[newdata.columns.str.contains('_mg')].values

# %%
newdata.drop(newdata.columns[newdata.columns.str.contains('_mg')].values,axis=1)

# %% [markdown]
# #เฉลย

# %%
##เฉลยจ้า
newdata_dropped = newdata.drop(['VitE_mg','Niacin_mg','Riboflavin_mg','Thiamin_mg','Magnesium_mg','Phosphorus_mg','Zinc_mg'], axis=1)
newdata_dropped
# Out:
#       Energy_kcal  Protein_g  ...  Selenium_USRDA  Zinc_USRDA
# 0           717.0       0.85  ...        0.018182    0.008182
# 1           717.0       0.85  ...        0.018182    0.004545
# 2           876.0       0.28  ...        0.000000    0.000909
# 3           353.0      21.40  ...        0.263636    0.241818
# 4           371.0      23.24  ...        0.263636    0.236364
# ...           ...        ...  ...             ...         ...
# 8613        305.0      18.50  ...        1.334545    0.100000
# 8614        111.0      20.54  ...        0.394545    0.140909
# 8615        269.0       0.00  ...        0.012727    0.017273
# 8616         90.0      16.10  ...        0.498182    0.090909
# 8617         89.0      19.80  ...        0.305455    0.090909
#
# [8618 rows x 31 columns]

# %%
data_dropped = data.drop(['ID','ShortDescrip','Descrip','CommonName','MfgName','ScientificName','VitE_mg','Niacin_mg','Riboflavin_mg','Thiamin_mg','Magnesium_mg','Phosphorus_mg','Zinc_mg'], axis=1)
data_dropped
# Out:
#                            FoodGroup  Energy_kcal  ...  Selenium_USRDA  Zinc_USRDA
# 0             Dairy and Egg Products        717.0  ...        0.018182    0.008182
# 1             Dairy and Egg Products        717.0  ...        0.018182    0.004545
# 2             Dairy and Egg Products        876.0  ...        0.000000    0.000909
# 3             Dairy and Egg Products        353.0  ...        0.263636    0.241818
# 4             Dairy and Egg Products        371.0  ...        0.263636    0.236364
# ...                              ...          ...  ...             ...         ...
# 8613  Finfish and Shellfish Products        305.0  ...        1.334545    0.100000
# 8614  Finfish and Shellfish Products        111.0  ...        0.394545    0.140909
# 8615                          Sweets        269.0  ...        0.012727    0.017273
# 8616  Finfish and Shellfish Products         90.0  ...        0.498182    0.090909
# 8617  Finfish and Shellfish Products         89.0  ...        0.305455    0.090909
#
# [8618 rows x 32 columns]

# %%
pd.plotting.parallel_coordinates(data_dropped,'FoodGroup',cols=['Protein_g','Fat_g','Carb_g','Sugar_g',	'Fiber_g'])

# %% [markdown]
# # ทำ CPA เพื่อลดจำนวน Dimention

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
new_pca = pca.fit_transform(newdata_dropped.to_numpy())

# %%
new_pca.shape
# Out:
# (8618, 2)

# %%
new_pca.shape
# Out:
# (8618, 2)

# %%
new_pca
# Out:
# array([[ 590.95286674,   85.56968946],
#        [ 590.95284476,   85.57159456],
#        [ 747.5994042 ,  117.79120834],
#        ...,
#        [ -95.72739188,  -53.51885094],
#        [ -66.70492177, -118.10632681],
#        [ -65.40356382,  -28.88067151]])

# %% [markdown]
# หาค่าที่เป็นไปได้ทั้งหมด

# %%
FG = set(data['FoodGroup'])
FG
# Out:
# {'American Indian/Alaska Native Foods',
#  'Baby Foods',
#  'Baked Products',
#  'Beef Products',
#  'Beverages',
#  'Breakfast Cereals',
#  'Cereal Grains and Pasta',
#  'Dairy and Egg Products',
#  'Fast Foods',
#  'Fats and Oils',
#  'Finfish and Shellfish Products',
#  'Fruits and Fruit Juices',
#  'Lamb, Veal, and Game Products',
#  'Legumes and Legume Products',
#  'Meals, Entrees, and Side Dishes',
#  'Nut and Seed Products',
#  'Pork Products',
#  'Poultry Products',
#  'Restaurant Foods',
#  'Sausages and Luncheon Meats',
#  'Snacks',
#  'Soups, Sauces, and Gravies',
#  'Spices and Herbs',
#  'Sweets',
#  'Vegetables and Vegetable Products'}

# %%
color_list = {}
num = 0
for each_fg in FG:
    if each_fg not in color_list:
        color_list[each_fg] = num
        num += 1

# %%
color_list
# Out:
# {'American Indian/Alaska Native Foods': 13,
#  'Baby Foods': 20,
#  'Baked Products': 22,
#  'Beef Products': 1,
#  'Beverages': 3,
#  'Breakfast Cereals': 7,
#  'Cereal Grains and Pasta': 23,
#  'Dairy and Egg Products': 6,
#  'Fast Foods': 18,
#  'Fats and Oils': 16,
#  'Finfish and Shellfish Products': 11,
#  'Fruits and Fruit Juices': 17,
#  'Lamb, Veal, and Game Products': 8,
#  'Legumes and Legume Products': 2,
#  'Meals, Entrees, and Side Dishes': 9,
#  'Nut and Seed Products': 24,
#  'Pork Products': 12,
#  'Poultry Products': 14,
#  'Restaurant Foods': 15,
#  'Sausages and Luncheon Meats': 0,
#  'Snacks': 21,
#  'Soups, Sauces, and Gravies': 19,
#  'Spices and Herbs': 5,
#  'Sweets': 10,
#  'Vegetables and Vegetable Products': 4}

# %%
data_dropped2 = data_dropped.replace(color_list)

# %%
data_dropped2
# Out:
#       FoodGroup  Energy_kcal  ...  Selenium_USRDA  Zinc_USRDA
# 0             6        717.0  ...        0.018182    0.008182
# 1             6        717.0  ...        0.018182    0.004545
# 2             6        876.0  ...        0.000000    0.000909
# 3             6        353.0  ...        0.263636    0.241818
# 4             6        371.0  ...        0.263636    0.236364
# ...         ...          ...  ...             ...         ...
# 8613         11        305.0  ...        1.334545    0.100000
# 8614         11        111.0  ...        0.394545    0.140909
# 8615         10        269.0  ...        0.012727    0.017273
# 8616         11         90.0  ...        0.498182    0.090909
# 8617         11         89.0  ...        0.305455    0.090909
#
# [8618 rows x 32 columns]

# %%
plt.scatter(new_pca[:,0],new_pca[:,1],c = data_dropped2['FoodGroup'])

# %%
plt.scatter(new_pca[:,0],new_pca[:,1],c = data_dropped2['FoodGroup'],alpha=0.5)

# %%
bb = data_dropped2[(data_dropped2['FoodGroup']==24) | (data_dropped2['FoodGroup']==9)]  ## ใช้  | และ  &  แทน  or  และ  and  ใน pandas
bb
# Out:
#       FoodGroup  Energy_kcal  ...  Selenium_USRDA  Zinc_USRDA
# 3638         24        191.0  ...        0.000000    0.081818
# 3639         24        168.0  ...        0.000000    0.075455
# 3640         24        217.0  ...        0.000000    0.102727
# 3641         24        367.0  ...        0.034545    0.173636
# 3642         24        486.0  ...        1.003636    0.416364
# ...         ...          ...  ...             ...         ...
# 8091          9        145.0  ...        0.305455    0.057273
# 8092          9        334.0  ...        0.467273    0.126364
# 8093          9        125.0  ...        0.174545    0.027273
# 8094          9        139.0  ...        0.000000    0.000000
# 8095          9        119.0  ...        0.000000    0.027273
#
# [246 rows x 32 columns]

# %%
pca = PCA(n_components=2)
new_pca = pca.fit_transform(bb.iloc[:,1:].to_numpy())

# %%
plt.scatter(new_pca[:,0],new_pca[:,1],c = bb['FoodGroup'],alpha=0.5)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.50110208, 0.24387404])
