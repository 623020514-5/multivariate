# %% [markdown]
# <a href="https://colab.research.google.com/github/623020514-5/multivariate/blob/main/PCA_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('nndb_flat.csv')
data.head(10)
# Out:
#      ID               FoodGroup  ... Selenium_USRDA Zinc_USRDA
# 0  1001  Dairy and Egg Products  ...       0.018182   0.008182
# 1  1002  Dairy and Egg Products  ...       0.018182   0.004545
# 2  1003  Dairy and Egg Products  ...       0.000000   0.000909
# 3  1004  Dairy and Egg Products  ...       0.263636   0.241818
# 4  1005  Dairy and Egg Products  ...       0.263636   0.236364
# 5  1006  Dairy and Egg Products  ...       0.263636   0.216364
# 6  1007  Dairy and Egg Products  ...       0.263636   0.216364
# 7  1008  Dairy and Egg Products  ...       0.263636   0.267273
# 8  1009  Dairy and Egg Products  ...       0.514545   0.311818
# 9  1010  Dairy and Egg Products  ...       0.263636   0.253636
#
# [10 rows x 45 columns]

# %% [markdown]
# ตรวจสอบข้อมูลว่ามี data กี่ตัว dimention
#
# 1.   List item
# 2.   List item

# %%
data.shape
# Out:
# (8618, 45)

# %% [markdown]
# ลอง plot scatter

# %%
pd.plotting.scatter_matrix(data)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f64fbd81210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fbd5c6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fbd14d10>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fb55f110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fb511690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fb4c8c10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f64fb48a1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fb43d750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fb3f3cd0>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fac91190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fac46810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fabfbe90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f64fabbd550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fab74bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fab34290>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fa3e24d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fa398a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64fa3329d0>],
#        ...,
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f64e81a6110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e815b690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e8110c10>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e7939a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e78eef90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e78b1550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f64e78e4ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e7881a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e785c650>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e7084450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e70399d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e6feff50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f64e6fb0510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e6fe5a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64eea90c10>,
#         ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e67c2dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e6783390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f64e6738910>]],
#       dtype=object)

# %% [markdown]
# เนื่องจาก Data มี dimention มากเกินไป เราจะทดสอบดูว่า column ใด ให้ข้อมูลซ้ำกับ column อื่น แล้วลบมันออก

# %%
newdata = data.iloc[:,7:]
newdata.head()
# Out:
#    Energy_kcal  Protein_g  Fat_g  ...  Phosphorus_USRDA  Selenium_USRDA  Zinc_USRDA
# 0        717.0       0.85  81.11  ...          0.034286        0.018182    0.008182
# 1        717.0       0.85  81.11  ...          0.032857        0.018182    0.004545
# 2        876.0       0.28  99.48  ...          0.004286        0.000000    0.000909
# 3        353.0      21.40  28.74  ...          0.552857        0.263636    0.241818
# 4        371.0      23.24  29.68  ...          0.644286        0.263636    0.236364
#
# [5 rows x 38 columns]

# %% [markdown]
# ตรวจสอบว่า ระหว่าง columns มี correlation กันมากน้อยแค่ไหน ด้วย numpy

# %%
import numpy as np

# %%
corr = np.corrcoef(newdata.to_numpy().T)

# %%
corr
# Out:
# array([[1.        , 0.11030203, 0.80679472, ..., 0.19518065, 0.05667274,
#         0.11276635],
#        [0.11030203, 1.        , 0.05471538, ..., 0.44460761, 0.37836917,
#         0.41631538],
#        [0.80679472, 0.05471538, 1.        , ..., 0.06608644, 0.03755914,
#         0.02826352],
#        ...,
#        [0.19518065, 0.44460761, 0.06608644, ..., 1.        , 0.22368557,
#         0.26657694],
#        [0.05667274, 0.37836917, 0.03755914, ..., 0.22368557, 1.        ,
#         0.20529859],
#        [0.11276635, 0.41631538, 0.02826352, ..., 0.26657694, 0.20529859,
#         1.        ]])

# %%
for i in range(corr.shape[0]): 
   for j in range(corr.shape[1]):
      if (i !=j) and (corr[i,j] == 1.):
        print(f'row = {i} column = {j} corrcoef = {corr[i,j]}')
# Out:
# row = 10 column = 27 corrcoef = 1.0
# row = 12 column = 29 corrcoef = 1.0
# row = 13 column = 30 corrcoef = 1.0
# row = 14 column = 31 corrcoef = 1.0
# row = 18 column = 34 corrcoef = 1.0
# row = 20 column = 35 corrcoef = 1.0
# row = 22 column = 37 corrcoef = 1.0
# row = 27 column = 10 corrcoef = 1.0
# row = 29 column = 12 corrcoef = 1.0
# row = 30 column = 13 corrcoef = 1.0
# row = 31 column = 14 corrcoef = 1.0
# row = 34 column = 18 corrcoef = 1.0
# row = 35 column = 20 corrcoef = 1.0
# row = 37 column = 22 corrcoef = 1.0

# %%
newdata.iloc[:5,11:29]
# Out:
#    Folate_mcg  Niacin_mg  Riboflavin_mg  ...  VitC_USRDA  VitE_USRDA  Folate_USRDA
# 0         3.0      0.042          0.034  ...         0.0    0.154667        0.0075
# 1         3.0      0.042          0.034  ...         0.0    0.154667        0.0075
# 2         0.0      0.003          0.005  ...         0.0    0.186667        0.0000
# 3        36.0      1.016          0.382  ...         0.0    0.016667        0.0900
# 4        20.0      0.118          0.351  ...         0.0    0.017333        0.0500
#
# [5 rows x 18 columns]

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(newdata.iloc[:,11],newdata.iloc[:,28])

# %%
plt.plot(newdata.iloc[:,11],newdata.iloc[:,28],'r.')

# %% [markdown]
# # Quiz1 ลบ columns ที่มีค่า
